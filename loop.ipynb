# %%
import pdb

# %%
n = 20

# %%
for i in range(n,1,-4):
    pdb.set_trace()
    print(i)
# Out:
#     [... skipping 21 hidden frame(s)]
# > /var/folders/4m/9_xfhwhs05q7fnk8_1tqjgyc0000gn/T/ipykernel_73714/420736274.py(2)<module>()
#       1 for i in range(n,1,-4):
# ----> 2     pdb.set_trace()
#       3     print(i)
#
# 20
# 20
# 19
# 18
# 17
# 17
# 17
# 17
# 17
# 16
# 15
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 1
# 2
# 12
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 33
# 3
# 3
# 3
# 3
# 333
# 333
# 333
# 333
# 33
# 22
# 22
# 22
# 10
# 10
